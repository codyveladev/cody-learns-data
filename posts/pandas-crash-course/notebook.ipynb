# %% [raw]
# ---
# title: "My Notebook"
# author: "Cody Vela"
# date: "2026-01-15"
# categories: [foundations, code]
# format:
#   html:
#     cold-fold:true
# ---

# %% [markdown]
# This is the entry of what we are trying to see here!

# %%
arr = [1,2,3]
print(arr)
